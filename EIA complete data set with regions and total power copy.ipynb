# %%
import pandas as pd
import json
import requests
from dotenv import load_dotenv, find_dotenv
import os
import hvplot.pandas
import matplotlib.pyplot as plt
from prophet import Prophet
load_dotenv(find_dotenv("local_keys.env"))
# Out:
# True

# %%
eia_key = os.getenv("eia")

# %%
type(eia_key)
# Out:
# str

# %%
fl_url = f"https://api.eia.gov/v2/electricity/retail-sales/data/?api_key={eia_key}&frequency=monthly&data[0]=price&data[1]=sales&facets[stateid][]=FL&facets[sectorid][]=ALL&start=2019-01&end=2023-12&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"

# %%
eia_response = requests.get(fl_url)

# %%
eia_data = eia_response.json()

# %%
print(json.dumps(eia_data, indent=4))
# Out:
# {
#     "response": {
#         "total": "60",
#         "dateFormat": "YYYY-MM",
#         "frequency": "monthly",
#         "data": [
#             {
#                 "period": "2023-12",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "13.39",
#                 "sales": "17740.90414",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2023-11",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "13.43",
#                 "sales": "17961.97285",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2023-10",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "13.58",
#                 "sales": "20985.83469",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2023-09",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "13.74",
#                 "sales": "24487.73919",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2023-08",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "13.31",
#                 "sales": "26956.2963",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2023-07",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "13.34",
#                 "sales": "26032.87123",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2023-06",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "13.5",
#                 "sales": "22784.21586",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2023-05",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "13.32",
#                 "sales": "20632.68671",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2023-04",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "13.85",
#                 "sales": "19218.31959",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2023-03",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "13.18",
#                 "sales": "18672.13013",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2023-02",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "13.99",
#                 "sales": "16868.39396",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2023-01",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "13.55",
#                 "sales": "18399.07903",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2022-12",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "12.7",
#                 "sales": "18819.5626",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2022-11",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "12.58",
#                 "sales": "18222.74909",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2022-10",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "12.76",
#                 "sales": "19758.44963",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2022-09",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "13.08",
#                 "sales": "23226.35526",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2022-08",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "12.73",
#                 "sales": "25801.87745",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2022-07",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "12.59",
#                 "sales": "25598.37486",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2022-06",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "12.49",
#                 "sales": "23518.80973",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2022-05",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "12.17",
#                 "sales": "21317.42929",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2022-04",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "12.21",
#                 "sales": "18462.79489",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2022-03",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "12.05",
#                 "sales": "18739.9783",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2022-02",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "12.51",
#                 "sales": "17215.89938",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2022-01",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "12.03",
#                 "sales": "18138.52253",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2021-12",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.8",
#                 "sales": "18357.68697",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2021-11",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "11.24",
#                 "sales": "16615.54538",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2021-10",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.84",
#                 "sales": "21325.13161",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2021-09",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "11.04",
#                 "sales": "23143.46995",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2021-08",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.63",
#                 "sales": "24617.01449",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2021-07",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.56",
#                 "sales": "23857.14557",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2021-06",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.62",
#                 "sales": "22220.7054",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2021-05",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.51",
#                 "sales": "20358.42362",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2021-04",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.35",
#                 "sales": "18002.29822",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2021-03",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.32",
#                 "sales": "17989.94643",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2021-02",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.71",
#                 "sales": "17135.12051",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2021-01",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.35",
#                 "sales": "17939.59384",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2020-12",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.29",
#                 "sales": "17864.97909",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2020-11",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.38",
#                 "sales": "18496.54066",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2020-10",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.22",
#                 "sales": "21040.06129",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2020-09",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.43",
#                 "sales": "22955.28069",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2020-08",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.09",
#                 "sales": "24982.87265",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2020-07",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.22",
#                 "sales": "24655.63867",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2020-06",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.06",
#                 "sales": "22229.86186",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2020-05",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "8.46",
#                 "sales": "19310.72037",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2020-04",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.22",
#                 "sales": "18600.77317",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2020-03",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.05",
#                 "sales": "18071.12615",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2020-02",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.17",
#                 "sales": "16678.79927",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2020-01",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.05",
#                 "sales": "17553.51711",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2019-12",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.33",
#                 "sales": "17289.81831",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2019-11",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.76",
#                 "sales": "17831.26089",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2019-10",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.38",
#                 "sales": "21596.57412",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2019-09",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.56",
#                 "sales": "23358.24041",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2019-08",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.47",
#                 "sales": "23901.98943",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2019-07",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.5",
#                 "sales": "23879.28629",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2019-06",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.51",
#                 "sales": "22634.62061",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2019-05",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.25",
#                 "sales": "20583.78364",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2019-04",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.29",
#                 "sales": "17847.81044",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2019-03",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.34",
#                 "sales": "17346.90223",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2019-02",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.47",
#                 "sales": "16527.12967",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             },
#             {
#                 "period": "2019-01",
#                 "stateid": "FL",
#                 "stateDescription": "Florida",
#                 "sectorid": "ALL",
#                 "sectorName": "all sectors",
#                 "price": "10.44",
#                 "sales": "17550.53901",
#                 "price-units": "cents per kilowatt-hour",
#                 "sales-units": "million kilowatt hours"
#             }
#         ],
#         "description": "Electricity sales to ultimate customer by state and sector (number of customers, average price, revenue, and megawatthours of sales).  \n    Sources: Forms EIA-826, EIA-861, EIA-861M"
#     },
#     "request": {
#         "command": "/v2/electricity/retail-sales/data/",
#         "params": {
#             "api_key": "ef9ylDxtxjwKzq7UZOH23iroZkUbi0PicRCovfF0",
#             "frequency": "monthly",
#             "data": [
#                 "price",
#                 "sales"
#             ],
#             "facets": {
#                 "stateid": [
#                     "FL"
#                 ],
#                 "sectorid": [
#                     "ALL"
#                 ]
#             },
#             "start": "2019-01",
#             "end": "2023-12",
#             "sort": [
#                 {
#                     "column": "period",
#                     "direction": "desc"
#                 }
#             ],
#             "offset": "0",
#             "length": "5000"
#         }
#     },
#     "apiVersion": "2.1.7",
#     "ExcelAddInVersion": "2.1.0"
# }

# %%
energy = pd.json_normalize(eia_data)
fl_df_energy = energy.explode("response.data")
fl_df_energy.head()
# Out:
#   apiVersion ExcelAddInVersion response.total response.dateFormat  \
# 0      2.1.7             2.1.0             60             YYYY-MM
# 0      2.1.7             2.1.0             60             YYYY-MM
# 0      2.1.7             2.1.0             60             YYYY-MM
# 0      2.1.7             2.1.0             60             YYYY-MM
# 0      2.1.7             2.1.0             60             YYYY-MM
#
#   response.frequency  \
# 0            monthly
# 0            monthly
# 0            monthly
# 0            monthly
# 0            monthly
#
#                                                                                                                                                                                                                                         response.data  \
# 0  {'period': '2023-12', 'stateid': 'FL', 'stateDescription': 'Florida', 'sectorid': 'ALL', 'sectorName': 'all sectors', 'price': '13.39', 'sales': '17740.90414', 'price-units': 'cents per kilowatt-hour', 'sales-units': 'million kilowatt hours'}
# 0  {'period': '2023-11', 'stateid': 'FL', 'stateDescription': 'Florida', 'sectorid': 'ALL', 'sectorName': 'all sectors', 'price': '13.43', 'sales': '17961.97285', 'price-units': 'cents per kilowatt-hour', 'sales-units': 'million kilowatt hours'}
# 0  {'period': '2023-10', 'stateid': 'FL', 'stateDescription': 'Florida', 'sectorid': 'ALL', 'sectorName': 'all sectors', 'price': '13.58', 'sales': '20985.83469', 'price-units': 'cents per kilowatt-hour', 'sales-units': 'million kilowatt hours'}
# 0  {'period': '2023-09', 'stateid': 'FL', 'stateDescription': 'Florida', 'sectorid': 'ALL', 'sectorName': 'all sectors', 'price': '13.74', 'sales': '24487.73919', 'price-units': 'cents per kilowatt-hour', 'sales-units': 'million kilowatt hours'}
# 0   {'period': '2023-08', 'stateid': 'FL', 'stateDescription': 'Florida', 'sectorid': 'ALL', 'sectorName': 'all sectors', 'price': '13.31', 'sales': '26956.2963', 'price-units': 'cents per kilowatt-hour', 'sales-units': 'million kilowatt hours'}
#
#                                                                                                                                                                      response.description  \
# 0  Electricity sales to ultimate customer by state and sector (number of customers, average price, revenue, and megawatthours of sales).  \n    Sources: Forms EIA-826, EIA-861, EIA-861M
# 0  Electricity sales to ultimate customer by state and sector (number of customers, average price, revenue, and megawatthours of sales).  \n    Sources: Forms EIA-826, EIA-861, EIA-861M
# 0  Electricity sales to ultimate customer by state and sector (number of customers, average price, revenue, and megawatthours of sales).  \n    Sources: Forms EIA-826, EIA-861, EIA-861M
# 0  Electricity sales to ultimate customer by state and sector (number of customers, average price, revenue, and megawatthours of sales).  \n    Sources: Forms EIA-826, EIA-861, EIA-861M
# 0  Electricity sales to ultimate customer by state and sector (number of customers, average price, revenue, and megawatthours of sales).  \n    Sources: Forms EIA-826, EIA-861, EIA-861M
#
#                       request.command  \
# 0  /v2/electricity/retail-sales/data/
# 0  /v2/electricity/retail-sales/data/
# 0  /v2/electricity/retail-sales/data/
# 0  /v2/electricity/retail-sales/data/
# 0  /v2/electricity/retail-sales/data/
#
#                      request.params.api_key request.params.frequency  \
# 0  ef9ylDxtxjwKzq7UZOH23iroZkUbi0PicRCovfF0                  monthly
# 0  ef9ylDxtxjwKzq7UZOH23iroZkUbi0PicRCovfF0                  monthly
# 0  ef9ylDxtxjwKzq7UZOH23iroZkUbi0PicRCovfF0                  monthly
# 0  ef9ylDxtxjwKzq7UZOH23iroZkUbi0PicRCovfF0                  monthly
# 0  ef9ylDxtxjwKzq7UZOH23iroZkUbi0PicRCovfF0                  monthly
#
#   request.params.data request.params.facets.stateid  \
# 0      [price, sales]                          [FL]
# 0      [price, sales]                          [FL]
# 0      [price, sales]                          [FL]
# 0      [price, sales]                          [FL]
# 0      [price, sales]                          [FL]
#
#   request.params.facets.sectorid request.params.start request.params.end  \
# 0                          [ALL]              2019-01            2023-12
# 0                          [ALL]              2019-01            2023-12
# 0                          [ALL]              2019-01            2023-12
# 0                          [ALL]              2019-01            2023-12
# 0                          [ALL]              2019-01            2023-12
#
#                            request.params.sort request.params.offset  \
# 0  [{'column': 'period', 'direction': 'desc'}]                     0
# 0  [{'column': 'period', 'direction': 'desc'}]                     0
# 0  [{'column': 'period', 'direction': 'desc'}]                     0
# 0  [{'column': 'period', 'direction': 'desc'}]                     0
# 0  [{'column': 'period', 'direction': 'desc'}]                     0
#
#   request.params.length
# 0                  5000
# 0                  5000
# 0                  5000
# 0                  5000
# 0                  5000

# %%
pd.set_option('display.max_colwidth', None)
fl_energy_data = fl_df_energy[['response.data']].reset_index().drop(columns='index').rename(columns={'response.data': 'data'})
fl_energy_data.head()
# Out:
#                                                                                                                                                                                                                                                  data
# 0  {'period': '2023-12', 'stateid': 'FL', 'stateDescription': 'Florida', 'sectorid': 'ALL', 'sectorName': 'all sectors', 'price': '13.39', 'sales': '17740.90414', 'price-units': 'cents per kilowatt-hour', 'sales-units': 'million kilowatt hours'}
# 1  {'period': '2023-11', 'stateid': 'FL', 'stateDescription': 'Florida', 'sectorid': 'ALL', 'sectorName': 'all sectors', 'price': '13.43', 'sales': '17961.97285', 'price-units': 'cents per kilowatt-hour', 'sales-units': 'million kilowatt hours'}
# 2  {'period': '2023-10', 'stateid': 'FL', 'stateDescription': 'Florida', 'sectorid': 'ALL', 'sectorName': 'all sectors', 'price': '13.58', 'sales': '20985.83469', 'price-units': 'cents per kilowatt-hour', 'sales-units': 'million kilowatt hours'}
# 3  {'period': '2023-09', 'stateid': 'FL', 'stateDescription': 'Florida', 'sectorid': 'ALL', 'sectorName': 'all sectors', 'price': '13.74', 'sales': '24487.73919', 'price-units': 'cents per kilowatt-hour', 'sales-units': 'million kilowatt hours'}
# 4   {'period': '2023-08', 'stateid': 'FL', 'stateDescription': 'Florida', 'sectorid': 'ALL', 'sectorName': 'all sectors', 'price': '13.31', 'sales': '26956.2963', 'price-units': 'cents per kilowatt-hour', 'sales-units': 'million kilowatt hours'}

# %%
fl_energy_df = fl_energy_data['data'].apply(pd.Series)
fl_energy_df['period'] = pd.to_datetime(fl_energy_df['period'])
fl_energy_df[['price', 'sales']] = fl_energy_df.loc[:, ['price', 'sales']].astype(float)
fl_energy_df = fl_energy_df.sort_index(ascending=False)
fl_energy_df.head()
# Out:
#        period stateid stateDescription sectorid   sectorName  price  \
# 59 2019-01-01      FL          Florida      ALL  all sectors  10.44
# 58 2019-02-01      FL          Florida      ALL  all sectors  10.47
# 57 2019-03-01      FL          Florida      ALL  all sectors  10.34
# 56 2019-04-01      FL          Florida      ALL  all sectors  10.29
# 55 2019-05-01      FL          Florida      ALL  all sectors  10.25
#
#           sales              price-units             sales-units
# 59  17550.53901  cents per kilowatt-hour  million kilowatt hours
# 58  16527.12967  cents per kilowatt-hour  million kilowatt hours
# 57  17346.90223  cents per kilowatt-hour  million kilowatt hours
# 56  17847.81044  cents per kilowatt-hour  million kilowatt hours
# 55  20583.78364  cents per kilowatt-hour  million kilowatt hours

# %%
fl_final_energy = fl_energy_df.drop(columns=['stateid', 'sectorid', 'stateDescription', 'sectorName', 'price-units', 'sales-units'])#.reset_index().drop(columns='index')
fl_final_energy = fl_final_energy.rename(columns={'period':'Date', "price": "cents/KWH", "sales": 'Sales in MillionKWH'})


fl_final_energy = fl_final_energy.groupby("Date")[['cents/KWH',  'Sales in MillionKWH']].sum()
fl_final_energy['Total Revenue'] = (fl_final_energy['cents/KWH'] / 100) * fl_final_energy['Sales in MillionKWH']

fl_final_energy.head()
# Out:
#             cents/KWH  Sales in MillionKWH  Total Revenue
# Date
# 2019-01-01      10.44          17550.53901    1832.276273
# 2019-02-01      10.47          16527.12967    1730.390476
# 2019-03-01      10.34          17346.90223    1793.669691
# 2019-04-01      10.29          17847.81044    1836.539694
# 2019-05-01      10.25          20583.78364    2109.837823

# %%
fl_final_energy = fl_final_energy.reset_index()


fl_total_energy_revenue =  fl_final_energy[['Date', 'Total Revenue']]
fl_total_energy_revenue.info()

# fl_total_energy_revenue.columns=['ds','y']
# fl_total_energy_revenue.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           60 non-null     datetime64[ns]
#  1   Total Revenue  60 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.1 KB

# %%
plt.figure(figsize=(20,8))
plt.plot(fl_total_energy_revenue['Date'].astype(str), fl_total_energy_revenue['Total Revenue'])
plt.xticks(rotation=90)
plt.xlabel('Date')
plt.ylabel('Total Revenue/Billion')
plt.title('Total Revenue of Florida Energy')
plt.grid()
plt.show()
